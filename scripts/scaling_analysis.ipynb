# %% [markdown]
# # Data Analysis for "Making Formulog Fast"
#
# This Jupyter Notebook analyzes our experimental data.
# It calculates the numbers reported in the paper, and also generates the figures and tables.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
import __main__ as main

if hasattr(main, "__file__"):
    import sys
    if len(sys.argv) != 3:
        print(f"usage: {sys.argv[0]} CSV_FILE TIMEOUT")
        exit(1)
    results_file = sys.argv[1]
    timeout = int(sys.argv[2])
else:
    os.chdir(os.path.join("..", "paper-results", "scaling"))
    results_file = "results.csv"
    timeout = 1800

# %% [markdown]
# ## Data Wrangling

# %%
data = pd.read_csv(results_file)
data.head()
# Out:
#   case_study benchmark             mode success  interpret_time  \
# 0     dminor     all-1  compile-reorder       y             NaN
# 1     dminor     all-1  compile-reorder       y             NaN
# 2     dminor     all-1  compile-reorder       y             NaN
# 3     dminor     all-1  compile-reorder       y             NaN
# 4     dminor     all-1  compile-reorder       y             NaN
#
#    interpret_cpu  interpret_mem  transpile_time  transpile_cpu  transpile_mem  \
# 0            NaN            NaN            0.91          376.0       0.478708
# 1            NaN            NaN             NaN            NaN            NaN
# 2            NaN            NaN            0.88          386.0       0.406868
# 3            NaN            NaN             NaN            NaN            NaN
# 4            NaN            NaN             NaN            NaN            NaN
#
#    ...  smt_calls  smt_time  smt_mode  smt_eval_time  smt_wait_time  \
# 0  ...       1006  0.607862  push-pop       0.607862            0.0
# 1  ...       1006  0.631769  push-pop       0.631769            0.0
# 2  ...       1006  0.846067  push-pop       0.846067            0.0
# 3  ...       1006  0.660414  push-pop       0.660414            0.0
# 4  ...       1006  0.670870  push-pop       0.670870            0.0
#
#    smt_cache_hits  smt_cache_misses  smt_cache_clears      work  parallelism
# 0        0.001553          0.004593                 0  0.123449            1
# 1        0.001553          0.004593                 0  0.123449            1
# 2        0.001447          0.004699                 0  0.123449            4
# 3        0.001406          0.004740                 0  0.123449            4
# 4        0.001443          0.004703                 0  0.123449            4
#
# [5 rows x 26 columns]

# %%
def get_time(row):
    if row["mode"].startswith("interpret"):
        val = row["interpret_time"]
    else:
        val = row["execute_time"]
    if pd.isnull(val):
        val = timeout
    return val

# %%
data["time"] = data.apply(get_time, axis=1)

# %%
def get_cpu(row):
    if row["mode"].startswith("interpret"):
        val = row["interpret_cpu"]
    else:
        val = row["execute_cpu"]
    return val

# %%
data["cpu"] = data.apply(get_cpu, axis=1)

# %%
def get_mem(row):
    if row["mode"].startswith("interpret"):
        val = row["interpret_mem"]
    else:
        val = row["execute_mem"]
    return val

# %%
data["mem"] = data.apply(get_mem, axis=1)

# %%
data
# Out:
#    case_study  benchmark               mode success  interpret_time  \
# 0      dminor      all-1    compile-reorder       y             NaN
# 1      dminor      all-1    compile-reorder       y             NaN
# 2      dminor      all-1    compile-reorder       y             NaN
# 3      dminor      all-1    compile-reorder       y             NaN
# 4      dminor      all-1    compile-reorder       y             NaN
# ..        ...        ...                ...     ...             ...
# 83      symex  shuffle-4  compile-unbatched       y             NaN
# 84      symex  shuffle-4  compile-unbatched       y             NaN
# 85      symex  shuffle-4  compile-unbatched       y             NaN
# 86      symex  shuffle-4  compile-unbatched       y             NaN
# 87      symex  shuffle-4  compile-unbatched       y             NaN
#
#     interpret_cpu  interpret_mem  transpile_time  transpile_cpu  \
# 0             NaN            NaN            0.91          376.0
# 1             NaN            NaN             NaN            NaN
# 2             NaN            NaN            0.88          386.0
# 3             NaN            NaN             NaN            NaN
# 4             NaN            NaN             NaN            NaN
# ..            ...            ...             ...            ...
# 83            NaN            NaN             NaN            NaN
# 84            NaN            NaN             NaN            NaN
# 85            NaN            NaN             NaN            NaN
# 86            NaN            NaN             NaN            NaN
# 87            NaN            NaN             NaN            NaN
#
#     transpile_mem  ...  smt_eval_time  smt_wait_time  smt_cache_hits  \
# 0        0.478708  ...       0.607862       0.000000        0.001553
# 1             NaN  ...       0.631769       0.000000        0.001553
# 2        0.406868  ...       0.846067       0.000000        0.001447
# 3             NaN  ...       0.660414       0.000000        0.001406
# 4             NaN  ...       0.670870       0.000000        0.001443
# ..            ...  ...            ...            ...             ...
# 83            NaN  ...       0.994452       0.053941        0.015006
# 84            NaN  ...       1.033690       0.044935        0.015011
# 85            NaN  ...       1.041780       0.054338        0.015014
# 86            NaN  ...       0.995464       0.064448        0.015000
# 87            NaN  ...       1.017890       0.056343        0.015012
#
#     smt_cache_misses  smt_cache_clears      work  parallelism  time  cpu  \
# 0           0.004593                 0  0.123449            1  0.80  107
# 1           0.004593                 0  0.123449            1  0.83  108
# 2           0.004699                 0  0.123449            4  0.90  220
# 3           0.004740                 0  0.123449            4  0.84  213
# 4           0.004703                 0  0.123449            4  0.87  212
# ..               ...               ...       ...          ...   ...  ...
# 83          0.000367                 0  0.471154            8  0.27  686
# 84          0.000362                 0  0.471158            8  0.26  705
# 85          0.000359                 0  0.471190            8  0.28  679
# 86          0.000373                 0  0.471214            8  0.27  685
# 87          0.000361                 0  0.471299            8  0.27  698
#
#          mem
# 0   0.045036
# 1   0.044872
# 2   0.042376
# 3   0.043720
# 4   0.043464
# ..       ...
# 83  0.040368
# 84  0.041128
# 85  0.042532
# 86  0.042460
# 87  0.039176
#
# [88 rows x 29 columns]

# %%
# Rename modes according to what we use in the paper
new_mode_names = {
    "interpret": "interpret",
    "interpret-reorder": "interpret",
    "interpret-unbatched": "interpret-eager",
    "compile": "compile",
    "compile-reorder": "compile",
    "compile-unbatched": "compile-eager",
    "klee": "klee",
    "cbmc": "cbmc",
    "scuba": "scuba",
}

data["mode"] = data["mode"].map(new_mode_names)

# %%
medians = data.groupby(["case_study", "benchmark", "mode", "parallelism"]).agg(
    {
        "smt_time": ["median"],
        "smt_cache_clears": ["median"],
        "time": ["median"],
        "work": ["median"],
        "cpu": ["median"],
        "mem": ["median"],
        "smt_cache_misses": ["median"],
    }
)

# %%
medians.columns = [
    "median_smt_time",
    "median_smt_cache_clears",
    "median_time",
    "median_work",
    "median_cpu",
    "median_mem",
    "median_smt_cache_misses",
]
medians = medians.reset_index()

# %%
medians
# Out:
#    case_study  benchmark           mode  parallelism  median_smt_time  \
# 0      dminor      all-1        compile            1         0.619816
# 1      dminor      all-1        compile            4         0.667081
# 2      dminor      all-1        compile            8         0.755261
# 3      dminor      all-1  compile-eager            1         0.517374
# 4      dminor      all-1  compile-eager            4         0.680975
# 5      dminor      all-1  compile-eager            8         0.940054
# 6       symex  shuffle-4        compile            1         0.624397
# 7       symex  shuffle-4        compile            4         0.716288
# 8       symex  shuffle-4        compile            8         0.992994
# 9       symex  shuffle-4  compile-eager            1         0.595036
# 10      symex  shuffle-4  compile-eager            4         0.719102
# 11      symex  shuffle-4  compile-eager            8         1.082673
#
#     median_smt_cache_clears  median_time  median_work  median_cpu  median_mem  \
# 0                       0.0        0.815     0.123449       107.5    0.044954
# 1                       0.0        0.845     0.123449       212.0    0.043432
# 2                       0.0        1.080     0.123449       384.5    0.042606
# 3                       0.0        0.660     0.105223       108.0    0.045448
# 4                       0.0        0.275     0.108800       405.0    0.043080
# 5                       0.0        0.295     0.107960       698.0    0.042408
# 6                       0.0        0.845     0.510003       110.0    0.040330
# 7                       0.0        0.430     0.510003       337.5    0.039624
# 8                       0.0        0.525     0.510003       568.5    0.039176
# 9                       0.0        0.830     0.470962       110.5    0.040296
# 10                      0.0        0.290     0.470961       405.5    0.039528
# 11                      0.0        0.270     0.471187       701.5    0.042396
#
#     median_smt_cache_misses
# 0                  0.004593
# 1                  0.004727
# 2                  0.004776
# 3                  0.004533
# 4                  0.004584
# 5                  0.004630
# 6                  0.000055
# 7                  0.000206
# 8                  0.000402
# 9                  0.000055
# 10                 0.000194
# 11                 0.000362

# %%
medians["mode_x_parallelism"] = list(zip(medians["mode"], medians["parallelism"]))
medians.head()
# Out:
#   case_study benchmark           mode  parallelism  median_smt_time  \
# 0     dminor     all-1        compile            1         0.619816
# 1     dminor     all-1        compile            4         0.667081
# 2     dminor     all-1        compile            8         0.755261
# 3     dminor     all-1  compile-eager            1         0.517374
# 4     dminor     all-1  compile-eager            4         0.680975
#
#    median_smt_cache_clears  median_time  median_work  median_cpu  median_mem  \
# 0                      0.0        0.815     0.123449       107.5    0.044954
# 1                      0.0        0.845     0.123449       212.0    0.043432
# 2                      0.0        1.080     0.123449       384.5    0.042606
# 3                      0.0        0.660     0.105223       108.0    0.045448
# 4                      0.0        0.275     0.108800       405.0    0.043080
#
#    median_smt_cache_misses  mode_x_parallelism
# 0                 0.004593        (compile, 1)
# 1                 0.004727        (compile, 4)
# 2                 0.004776        (compile, 8)
# 3                 0.004533  (compile-eager, 1)
# 4                 0.004584  (compile-eager, 4)

# %%
# def stats(df, process_row):
#     def compute(df):
#         res = df.apply(process_row, axis=1).agg(["mean", "min", "median", "max"])
#         print(res)

#     print("all:")
#     compute(df)
#     print("\ndminor:")
#     compute(df[df["case_study"] == "dminor"])
#     print("\nscuba:")
#     compute(df[df["case_study"] == "scuba"])
#     print("\nsymex:")
#     compute(df[df["case_study"] == "symex"])


# def speedup(df, mode, baseline):
#     """Return the speedup of `mode` relative to `baseline`, calculated as
#     `baseline` divided by `mode`"""
#     def process_row(row):
#         if not pd.isnull(row[mode]):
#             return row[baseline] / row[mode]

#     return stats(df, process_row)


def widen(df, val):
    return df.pivot(
        index=["case_study", "benchmark"], columns="mode_x_parallelism", values=val
    ).reset_index()

# %%
times = widen(medians, "median_time")
smt_times = widen(medians, "median_smt_time")
work = widen(medians, "median_work")
cpu = widen(medians, "median_cpu")
mem = widen(medians, "median_mem")
smt_cache_misses = widen(medians, "median_smt_cache_misses")

# %%
def smt_heavy(df):
    return df[(df["case_study"] != "scuba")]

# %%
times
# Out:
# mode_x_parallelism case_study  benchmark  (compile, 1)  (compile, 4)  \
# 0                      dminor      all-1         0.815         0.845
# 1                       symex  shuffle-4         0.845         0.430
#
# mode_x_parallelism  (compile, 8)  (compile-eager, 1)  (compile-eager, 4)  \
# 0                          1.080                0.66               0.275
# 1                          0.525                0.83               0.290
#
# mode_x_parallelism  (compile-eager, 8)
# 0                                0.295
# 1                                0.270

# %%
os.makedirs("figures", exist_ok=True)

# %%
# Scaling table

nthreads = (1, 8, 16, 24, 32, 40)

def make_table_row(row, acc):
    def time(mode, baseline):
        if pd.isnull(row[mode]):
            return "-"
        if row[mode] == timeout:
            return "TO"
        else:
            t = f"{row[mode]:0.2f}"
            bf = t == best
            if baseline != None and not pd.isnull(baseline):
                speedup = baseline / row[mode]
                t = f"{t} ({speedup:0.1f}$\\times$)"
            if bf:
                t = "{\\bf %s}" % t
            return t

    times = [row[(mode, j)] for mode in ("compile", "compile-eager") for j in nthreads]
    best = min(t for t in times if not pd.isnull(t))
    best = f"{best:0.2f}"

    s = []
    s.append(f"{row['case_study']} & {row['benchmark']}")
    for i, j in enumerate(nthreads):
        baseline = row[("compile", nthreads[0])] if i > 0 else None 
        s.extend([" & ", time(("compile", j), baseline)])
    s.extend([" &"])
    for i, j in enumerate(nthreads):
        baseline = row[("compile-eager", nthreads[0])] if i > 0 else None 
        s.extend([" & ", time(("compile-eager", j), baseline)])
    s.append(r"\\")
    acc.append("".join(s))


nconfigs = len(nthreads)
s = []
s.append(r"\documentclass{article}")
s.append(r"\usepackage{colortbl}")
s.append(r"\usepackage{multirow}")
s.append(r"\usepackage{color}")
s.append(r"\usepackage{booktabs}")
s.append(r"\definecolor{Gray}{gray}{0.9}")
s.append(r"\begin{document}")
s.append(r"\footnotesize")
s.append(r"\begin{tabular}{ll" + "r" * (2 * nconfigs + 1) + r"}")
s.append(r"\toprule")
s.append(
    r"& & \multicolumn{" + str(2 * nconfigs + 1) + r"}{c}{Number of threads (seconds and speedup over " + str(nthreads[0]) + r" thread)} \\"
)
s.append(
    r"& & \multicolumn{" + str(nconfigs) + r"}{c}{Semi-naive evaluation} & & \multicolumn{" + str(nconfigs) + r"}{c}{Eager evaluation} \\"
)
line1_end = 3 + nconfigs - 1
line2_start = line1_end + 2
line2_end = line2_start + nconfigs - 1
s.append(r"\cline{3-" + str(line1_end) + r"} \cline{" + str(line2_start) + "-" + str(line2_end) + r"}")
thread_header = " ".join([f"& {x}" for x in nthreads])
s.append(
    r"Case study & Benchmark" + thread_header + "& " + thread_header + r"\\"
)
s.append(r"\midrule")
times.apply(lambda row: make_table_row(row, s), axis=1)
s.append(r"\bottomrule")
s.append(r"\end{tabular}")
s.append(r"\end{document}")
with open(os.path.join("figures", "tab2.tex"), "w") as f:
    f.write("\n".join(s))
